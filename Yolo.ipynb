# %%
# %cd /content/drive/MyDrive/yolo-v4-tf.keras-master
# Out:
# /content/drive/MyDrive/yolo-v4-tf.keras-master

# %%
from models import Yolov4

# %%
model = Yolov4(weight_path='/content/drive/MyDrive/yolo-v4-tf.keras-master/yolov4.weights',class_name_path='/content/drive/MyDrive/yolo-v4-tf.keras-master/class_names/tl_classes.txt')
# Out:
# nms iou: 0.413 score: 0.3
# failed to read  all weights, # of unread weights: 0
# load from /content/drive/MyDrive/yolo-v4-tf.keras-master/yolov4.weights

# %%
from utils import DataGenerator, read_annotation_lines

# %%
train_lines, val_lines = read_annotation_lines('/content/drive/MyDrive/yolo-v4-tf.keras-master/tl_dataset/txt/anno.txt',test_size=0.1)

FOLDER_PATH = '/content/drive/MyDrive/yolo-v4-tf.keras-master/tl_dataset/img'
CN_PATH = '/content/drive/MyDrive/yolo-v4-tf.keras-master/class_names/tl_classes.txt'

data_gen_train = DataGenerator(train_lines,class_name_path=CN_PATH,folder_path=FOLDER_PATH)
data_gen_val = DataGenerator(val_lines,class_name_path=CN_PATH,folder_path=FOLDER_PATH)

# %%
model = Yolov4(class_name_path=CN_PATH)

model.fit(data_gen_train,initial_epoch=0,epochs=10,val_data_gen=data_gen_val)
# Out:
# nms iou: 0.413 score: 0.3
# Epoch 1/10
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 19s 19s/step - loss: 120968.0469 - val_loss: 118074.6406
# Epoch 2/10
# 1/1 [==============================] - 1s 623ms/step - loss: 127951.4141 - val_loss: 117594.0469
# Epoch 3/10
# 1/1 [==============================] - 1s 546ms/step - loss: 100878.7969 - val_loss: 117071.5078
# Epoch 4/10
# 1/1 [==============================] - 1s 550ms/step - loss: 80547.0312 - val_loss: 116272.7031
# Epoch 5/10
# 1/1 [==============================] - 1s 544ms/step - loss: 57413.1758 - val_loss: 115388.3906
# Epoch 6/10
# 1/1 [==============================] - 1s 547ms/step - loss: 43830.8281 - val_loss: 114162.6094
# Epoch 7/10
# ...

# %%
model.predict('/content/tl_test.jpg')
# Out:
# img shape:  (183, 276, 3)
# 1/1 [==============================] - 2s 2s/step
# # of bboxes: 0
# Empty DataFrame
# Columns: [x1, y1, x2, y2, class_name, score, w, h]
# Index: []
